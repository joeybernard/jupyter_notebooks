# %%
import numpy as np
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# %matplotlib notebook
from datetime import datetime

data = pd.read_csv("data_test.csv")

x = data['x']
y = data['y']
z = data['z']
t = data['t']

Bx = data['Bx']
By = data['By']
Bz = data['Bz']
B = np.sqrt(Bx**2 + By**2 + Bz**2)

# %%
fig1 = plt.figure()
ax1 = fig1.gca(projection='3d')
ax1.quiver(x, y, z, Bx.array, By.array, Bz.array, length=5)
#ax.scatter3D(x,y,z,c=B)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="911">

# %%
fig2 = plt.figure()
ax2 = fig2.gca(projection='3d')
#grad = np.gradient(B, x.array, y.array, z.array)
#ax2.scatter3D(x, y, z, grad)
ax2.scatter3D(x,y,z,c=B)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
dx = []
last = 0
for val in z:
    dx.append(val - last)
    print(last, ',',val)
    last = val

np.min(dx)
#np.mean(dx)
#np.max(dx)
#plt.plot(dx)
# Out:
# 0 , 5090
# 5090 , 5100
# 5100 , 5110
# 5110 , 5120
# 5120 , 5130
# 5130 , 5140
# 5140 , 5150
# 5150 , 5160
# 5160 , 5170
# 5170 , 5180
# 5180 , 5190
# 5190 , 5200
# 5200 , 5220
# 5220 , 5230
# 5230 , 5240
# 5240 , 5250
# 5250 , 5260
# 5260 , 5270
# 5270 , 5280
# 5280 , 5290
# 5290 , 5300
# 5300 , 5310
# 5310 , 5320
# 5320 , 5330
# 5330 , 5340
# 5340 , 5350
# 5350 , 5360
# 5360 , 5370
# 5370 , 5380
# 5380 , 5390
# 5390 , 5400
# 5400 , 5410
# 5410 , 5420
# 5420 , 5430
# 5430 , 5440
# 5440 , 5450
# 5450 , 5460
# 5460 , 5470
# 5470 , 5480
# 5480 , 5490
# 5490 , 5500
# 5500 , 5510
# 5510 , 5520
# 5520 , 5530
# 5530 , 5540
# 5540 , 5540
# 5540 , 5550
# 5550 , 5560
# 5560 , 5570
# 5570 , 5580
# 5580 , 5590
# 5590 , 5600
# 5600 , 5610
# 5610 , 5620
# 5620 , 5630
# 5630 , 5640
# 5640 , 5650
# 5650 , 5660
# 5660 , 5670
# 5670 , 5670
# 5670 , 5680
# 5680 , 5690
# 5690 , 5700
# 5700 , 5710
# 5710 , 5720
# 5720 , 5730
# 5730 , 5740
# 5740 , 5750
# 5750 , 5750
# 5750 , 5760
# 5760 , 5770
# ...

# %%
print(t)
# Out:
# 0     2019-05-13T03:50:00.000Z
# 1     2019-05-13T03:50:08.000Z
# 2     2019-05-13T03:50:16.000Z
# 3     2019-05-13T03:50:24.000Z
# 4     2019-05-13T03:50:32.000Z
#                 ...
# 71    2019-05-13T03:59:28.000Z
# 72    2019-05-13T03:59:36.000Z
# 73    2019-05-13T03:59:44.000Z
# 74    2019-05-13T03:59:52.000Z
# 75    2019-05-13T04:00:00.000Z
# Name: t, Length: 76, dtype: object

# %%
dates = pd.to_datetime(t, infer_datetime_format=True)

# %%
dates
# Out:
# 0    2019-05-13 03:50:00+00:00
# 1    2019-05-13 03:50:08+00:00
# 2    2019-05-13 03:50:16+00:00
# 3    2019-05-13 03:50:24+00:00
# 4    2019-05-13 03:50:32+00:00
#                 ...
# 71   2019-05-13 03:59:28+00:00
# 72   2019-05-13 03:59:36+00:00
# 73   2019-05-13 03:59:44+00:00
# 74   2019-05-13 03:59:52+00:00
# 75   2019-05-13 04:00:00+00:00
# Name: t, Length: 76, dtype: datetime64[ns, UTC]

# %%
plt.plot(dates, z)
# Out:
# <img src="data:image/png;base64,..." width="640">
